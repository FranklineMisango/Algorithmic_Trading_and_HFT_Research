# %% [markdown]
# # Canadian Bond Day Count Arbitrage - Data Exploration
#
# This notebook loads and explores Canadian Government bond data from Databento
# and yield curves from the Bank of Canada.
#
# ## Objectives
# 1. Load CGB futures data from Databento
# 2. Load yield curve data from Bank of Canada
# 3. Analyze price and volume patterns
# 4. Prepare data for arbitrage analysis

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from pathlib import Path

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.4f}'.format)

# Plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 7)

# %% [markdown]
# ## 1. Load Downloaded Data

# %%
# Load CGB futures data
data_dir = Path('../data')

# Try to load daily summary first (more manageable)
if (data_dir / 'cgb_futures_daily.csv').exists():
    cgb_data = pd.read_csv(data_dir / 'cgb_futures_daily.csv')
    cgb_data['timestamp'] = pd.to_datetime(cgb_data['timestamp'])
    print(f"✅ Loaded {len(cgb_data)} daily CGB records")
    print(f"Date range: {cgb_data['timestamp'].min()} to {cgb_data['timestamp'].max()}")
    cgb_data.head()
else:
    print("⚠️  CGB futures data not found. Run download_data.py first:")
    print("   python download_data.py")
    cgb_data = pd.DataFrame()

# %%
# Load Bank of Canada yield curve data
if (data_dir / 'boc_yield_curves.csv').exists():
    boc_data = pd.read_csv(data_dir / 'boc_yield_curves.csv')
    boc_data['date'] = pd.to_datetime(boc_data['date'])
    print(f"✅ Loaded {len(boc_data)} BoC yield curve observations")
    print(f"Date range: {boc_data['date'].min()} to {boc_data['date'].max()}")
    print(f"\nAvailable yield series: {len([col for col in boc_data.columns if col != 'date'])}")
    boc_data.head()
else:
    print("⚠️  BoC yield curve data not found. Run download_data.py first.")
    boc_data = pd.DataFrame()

# %% [markdown]
# ## 2. Data Overview

# %%
# Display CGB data overview
if len(cgb_data) > 0:
    print("CGB Futures Data Overview:")
    print(f"  Records: {len(cgb_data)}")
    print(f"  Unique symbols: {cgb_data['symbol'].nunique()}")
    print(f"  Symbols: {sorted(cgb_data['symbol'].unique().tolist())}")
    print(f"\n  Basic statistics:")
    print(cgb_data[['open', 'high', 'low', 'close', 'volume']].describe())

# %%
# Display BoC data overview
if len(boc_data) > 0:
    print("Bank of Canada Yield Curve Data Overview:")
    print(f"  Records: {len(boc_data)}")
    print(f"  Date range: {boc_data['date'].min()} to {boc_data['date'].max()}")
    
    # Show yield series
    yield_cols = [col for col in boc_data.columns if col != 'date']
    print(f"\n  Yield series ({len(yield_cols)} total):")
    for col in yield_cols[:10]:
        print(f"    - {col}")
    if len(yield_cols) > 10:
        print(f"    ... and {len(yield_cols) - 10} more")
    
    print(f"\n  Latest yields ({boc_data['date'].iloc[-1].date()}):")
    latest = boc_data.iloc[-1]
    for col in yield_cols[:5]:
        print(f"    {col}: {latest[col]}")

# %% [markdown]
# ## 3. CGB Futures Price Analysis

# %%
# Analyze CGB futures prices
if len(cgb_data) > 0:
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    
    # 1. Price time series by symbol
    symbols = sorted(cgb_data['symbol'].unique())
    for symbol in symbols[:5]:  # Plot first 5 symbols
        symbol_data = cgb_data[cgb_data['symbol'] == symbol].sort_values('timestamp')
        axes[0, 0].plot(symbol_data['timestamp'], symbol_data['close'], label=symbol, alpha=0.7, linewidth=2)
    
    axes[0, 0].set_xlabel('Date')
    axes[0, 0].set_ylabel('Close Price')
    axes[0, 0].set_title('CGB Futures Close Prices (Top 5 Symbols)')
    axes[0, 0].legend()
    axes[0, 0].tick_params(axis='x', rotation=45)
    axes[0, 0].grid(True, alpha=0.3)
    
    # 2. Volume distribution
    cgb_data['volume'].hist(bins=50, ax=axes[0, 1], edgecolor='black', color='steelblue')
    axes[0, 1].set_xlabel('Volume')
    axes[0, 1].set_ylabel('Frequency')
    axes[0, 1].set_title('Volume Distribution')
    axes[0, 1].set_yscale('log')
    
    # 3. Daily returns
    cgb_data_sorted = cgb_data.sort_values('timestamp')
    cgb_data_sorted['returns'] = cgb_data_sorted.groupby('symbol')['close'].pct_change() * 100
    cgb_data_sorted['returns'].hist(bins=50, ax=axes[1, 0], edgecolor='black', color='green', alpha=0.7)
    axes[1, 0].set_xlabel('Daily Return (%)')
    axes[1, 0].set_ylabel('Frequency')
    axes[1, 0].set_title('Daily Returns Distribution')
    
    # 4. Volume by symbol
    top_symbols = cgb_data.groupby('symbol')['volume'].sum().sort_values(ascending=False).head(10)
    top_symbols.plot(kind='bar', ax=axes[1, 1], color='coral')
    axes[1, 1].set_xlabel('Symbol')
    axes[1, 1].set_ylabel('Total Volume')
    axes[1, 1].set_title('Top 10 Symbols by Volume')
    axes[1, 1].tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()
    
    print("\nCGB Futures Statistics:")
    print(cgb_data[['open', 'high', 'low', 'close', 'volume']].describe())

# %% [markdown]
# ## 4. Yield Curve Analysis

# %%
# Analyze yield curves
if len(boc_data) > 0:
    # Extract yield series
    yield_cols = [col for col in boc_data.columns if col != 'date' and col.startswith('IRRGOVCO')]
    
    if len(yield_cols) > 0:
        fig, axes = plt.subplots(2, 1, figsize=(16, 10))
        
        # 1. Yield curve over time
        for col in yield_cols[:5]:  # Plot first 5 series
            yield_series = pd.to_numeric(boc_data[col], errors='coerce')
            axes[0].plot(boc_data['date'], yield_series, label=col, alpha=0.7, linewidth=2)
        
        axes[0].set_xlabel('Date')
        axes[0].set_ylabel('Yield (%)')
        axes[0].set_title('Government of Canada Bond Yields Over Time')
        axes[0].legend()
        axes[0].tick_params(axis='x', rotation=45)
        axes[0].grid(True, alpha=0.3)
        
        # 2. Latest yield curve
        latest = boc_data.iloc[-1]
        latest_yields = []
        labels = []
        for col in yield_cols:
            try:
                val = float(latest[col])
                latest_yields.append(val)
                labels.append(col.replace('IRRGOVCO', ''))
            except:
                pass
        
        if len(latest_yields) > 0:
            axes[1].plot(range(len(latest_yields)), latest_yields, marker='o', linewidth=2, markersize=8, color='darkblue')
            axes[1].set_xticks(range(len(latest_yields)))
            axes[1].set_xticklabels(labels, rotation=45)
            axes[1].set_xlabel('Maturity')
            axes[1].set_ylabel('Yield (%)')
            axes[1].set_title(f'Latest Yield Curve ({latest["date"].date()})')
            axes[1].grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()
        
        print("\nYield Curve Statistics:")
        numeric_yields = boc_data[yield_cols].apply(pd.to_numeric, errors='coerce')
        print(numeric_yields.describe())

# %% [markdown]
# ## 5. Data Quality & Completeness

# %%
# Check data quality
print("\n" + "="*70)
print("DATA QUALITY REPORT")
print("="*70)

if len(cgb_data) > 0:
    print("\n✅ CGB Futures Data:")
    print(f"   Records: {len(cgb_data):,}")
    print(f"   Date range: {cgb_data['timestamp'].min().date()} to {cgb_data['timestamp'].max().date()}")
    print(f"   Unique symbols: {cgb_data['symbol'].nunique()}")
    print(f"   Missing values:")
    for col in ['open', 'high', 'low', 'close', 'volume']:
        missing = cgb_data[col].isnull().sum()
        print(f"     {col}: {missing}")
else:
    print("\n❌ CGB Futures Data: NOT LOADED")

if len(boc_data) > 0:
    print("\n✅ Bank of Canada Yield Data:")
    print(f"   Records: {len(boc_data):,}")
    print(f"   Date range: {boc_data['date'].min().date()} to {boc_data['date'].max().date()}")
    yield_cols = [col for col in boc_data.columns if col != 'date']
    print(f"   Yield series: {len(yield_cols)}")
else:
    print("\n❌ Bank of Canada Yield Data: NOT LOADED")

print("\n" + "="*70)

# %% [markdown]
# ## 6. Next Steps

# %%
print("\n" + "="*70)
print("NEXT STEPS")
print("="*70)

if len(cgb_data) > 0 and len(boc_data) > 0:
    print("\n✅ Data successfully loaded!")
    print("\nReady for analysis:")
    print("  1. CGB futures data: Price, volume, and returns")
    print("  2. Yield curve data: Government bond yields across maturities")
    print("\nNext notebook: 02_day_count_analysis.ipynb")
    print("  - Analyze day count conventions")
    print("  - Identify arbitrage opportunities")
    print("  - Calculate theoretical profits")
else:
    print("\n⚠️  Data not fully loaded. Please run:")
    print("\n  python download_data.py")
    print("\nOptional: Specify date range")
    print("  python download_data.py 2024-01-01 2024-12-31")
    print("\nNote: Requires DATABENTO_API_KEY environment variable")

print("\n" + "="*70)

# %% [markdown]
# ## 7. Export Data

# %%
# Export processed data for further analysis
if len(cgb_data) > 0:
    cgb_data.to_csv('../data/cgb_processed.csv', index=False)
    print("✅ Saved CGB data to ../data/cgb_processed.csv")

if len(boc_data) > 0:
    boc_data.to_csv('../data/boc_processed.csv', index=False)
    print("✅ Saved BoC data to ../data/boc_processed.csv")

if len(cgb_data) > 0 and len(boc_data) > 0:
    print("\n✅ All data ready for analysis!")
