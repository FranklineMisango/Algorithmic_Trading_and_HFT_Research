# %% [markdown]
# # Currency Crash Prediction - Backtest Analysis
#
# Backtest the R-Zone strategy with transaction costs and risk management

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from signal_generator import CurrencyCrashPredictor
import yaml

sns.set_style('darkgrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load Signals and Configuration

# %%
with open('../config.yaml', 'r') as f:
    config = yaml.safe_load(f)

predictor = CurrencyCrashPredictor()
predictor.load_data()
signals = predictor.generate_signals()

fx_rates = predictor.fx_rates
r_zone = signals['r_zone']
monthly_returns = signals['monthly_returns']
# Out:
# 2026-03-02 17:31:28.198 | INFO     | signal_generator:load_data:38 - Loaded 228 months of data
# 2026-03-02 17:31:28.199 | INFO     | signal_generator:generate_signals:126 - Calculating features...
# 2026-03-02 17:31:28.201 | INFO     | signal_generator:generate_signals:129 - Calculating thresholds...
# 2026-03-02 17:31:28.217 | INFO     | signal_generator:generate_signals:132 - Generating R-Zone signals...
# 2026-03-02 17:31:28.222 | INFO     | signal_generator:generate_signals:135 - Identifying crashes...
# /home/misango/codechest/Algorithmic_Trading_and_HFT_Research/Algorithmic_Strategies/Currency_Crash_Prediction/notebooks/../signal_generator.py:172: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(
# 2026-03-02 17:31:28.333 | INFO     | signal_generator:calculate_statistics:198 -
# Statistics:
#    currency  r_zone_signals  crashes_after_signal  crash_prob_in_rzone  \
# ...

# %% [markdown]
# ## 2. Simple Backtest: Short on R-Zone Entry

# %%
def backtest_strategy(r_zone, monthly_returns, interest_rates, config):
    """
    Enhanced backtest: Short currency on R-Zone entry, hold up to 6 months with risk management
    Includes carry costs, position sizing, stop-losses, take-profits, and dynamic slippage
    """
    position_duration = config['position_duration_months']
    
    # Risk management parameters
    initial_capital = 1000000
    capital = initial_capital
    max_position_pct = 0.02  # 2% of capital per position
    stop_loss_pct = 0.10  # 10% loss threshold
    take_profit_pct = 0.20  # 20% gain threshold
    vol_lookback = 12  # Months for volatility calculation
    
    trades = []
    
    for currency in r_zone.columns:
        r_zone_dates = r_zone[r_zone[currency] == 1].index
        
        for entry_date in r_zone_dates:
            # Calculate position size based on volatility
            if len(monthly_returns) >= vol_lookback:
                currency_vol = monthly_returns[currency].rolling(vol_lookback).std().loc[:entry_date].iloc[-1]
                if pd.isna(currency_vol) or currency_vol == 0:
                    position_size = max_position_pct * capital
                else:
                    position_size = min(max_position_pct * capital, capital / (10 * currency_vol))
            else:
                position_size = max_position_pct * capital
            
            # Calculate exit dates
            exit_dates = pd.date_range(entry_date, periods=position_duration+1, freq='M')[1:]
            
            # Simulate holding period with risk management
            cumulative_return = 0
            carry_accrued = 0
            exit_reason = 'time_limit'
            actual_exit_date = exit_dates[-1]
            
            for i, date in enumerate(exit_dates):
                if date not in monthly_returns.index:
                    continue
                    
                # Monthly return (short position)
                ret = -monthly_returns.loc[date, currency]
                
                # Calculate monthly carry cost
                usd_rate = interest_rates.loc[interest_rates.index <= date, 'USD'].iloc[-1] / 100 / 12 if 'USD' in interest_rates.columns else 0
                curr_rate = interest_rates.loc[interest_rates.index <= date, currency].iloc[-1] / 100 / 12 if currency in interest_rates.columns else 0
                monthly_carry = usd_rate - curr_rate
                
                cumulative_return += ret
                carry_accrued += monthly_carry
                
                total_return = cumulative_return - carry_accrued
                
                # Check stop-loss and take-profit
                if total_return <= -stop_loss_pct:
                    exit_reason = 'stop_loss'
                    actual_exit_date = date
                    break
                elif total_return >= take_profit_pct:
                    exit_reason = 'take_profit'
                    actual_exit_date = date
                    break
            
            # Apply transaction costs and slippage
            currency_type = 'advanced' if currency in config['currencies']['advanced'] else 'emerging'
            tc = config['transaction_costs'][currency_type] / 10000  # bps to decimal
            base_slippage = config['slippage'][currency_type] / 10000
            dynamic_slippage = base_slippage * (1 + 0.5 * (position_size / capital))  # Market impact
            
            gross_return = cumulative_return - carry_accrued
            net_return = gross_return - 2 * (tc + dynamic_slippage)  # Entry + exit
            
            # Update capital (simplified - assumes position size is % of capital)
            capital *= (1 + net_return * (position_size / capital))
            
            trades.append({
                'currency': currency,
                'entry_date': entry_date,
                'exit_date': actual_exit_date,
                'gross_return': gross_return,
                'net_return': net_return,
                'holding_months': (actual_exit_date - entry_date).days / 30,
                'position_size': position_size,
                'exit_reason': exit_reason,
                'capital_after': capital
            })
    
    return pd.DataFrame(trades), capital

trades_df, final_capital = backtest_strategy(r_zone, monthly_returns, predictor.interest_rates, config)
print(f"Total Trades: {len(trades_df)}")
print(f"Initial Capital: $1,000,000")
print(f"Final Capital: ${final_capital:,.0f}")
print(f"Total Return: {((final_capital / 1000000) - 1) * 100:.1f}%")
print(f"\nFirst 10 trades:")
print(trades_df.head(10))
# Out:
# /tmp/ipykernel_297881/357081550.py:33: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   exit_dates = pd.date_range(entry_date, periods=position_duration+1, freq='M')[1:]
# Total Trades: 457
# Initial Capital: $1,000,000
# Final Capital: $1,405,816
# Total Return: 40.6%
#
# First 10 trades:
#   currency entry_date  exit_date  gross_return  net_return  holding_months  \
# 0      EUR 2008-09-30 2009-03-31      0.056296    0.053988        6.066667
# 1      EUR 2008-10-31 2009-04-30     -0.044240   -0.046548        6.033333
# 2      EUR 2010-02-28 2010-08-31      0.068957    0.066649        6.133333
# 3      EUR 2010-03-31 2010-09-30     -0.016030   -0.018338        6.100000
# 4      EUR 2010-04-30 2010-10-31     -0.042584   -0.044892        6.133333
# 5      EUR 2010-05-31 2010-09-30     -0.107955   -0.110263        4.066667
# 6      EUR 2010-06-30 2010-09-30     -0.112872   -0.115180        3.066667
# ...

# %% [markdown]
# ## 3. Performance Metrics

# %%
# Calculate performance metrics
win_rate = (trades_df['net_return'] > 0).mean()
avg_return = trades_df['net_return'].mean()
avg_win = trades_df[trades_df['net_return'] > 0]['net_return'].mean()
avg_loss = trades_df[trades_df['net_return'] < 0]['net_return'].mean()
profit_factor = abs(avg_win / avg_loss) if avg_loss != 0 else np.nan

print("=" * 50)
print("BACKTEST PERFORMANCE METRICS")
print("=" * 50)
print(f"Total Trades: {len(trades_df)}")
print(f"Win Rate: {win_rate:.2%}")
print(f"Average Return per Trade: {avg_return:.2%}")
print(f"Average Win: {avg_win:.2%}")
print(f"Average Loss: {avg_loss:.2%}")
print(f"Profit Factor: {profit_factor:.2f}")
print(f"Best Trade: {trades_df['net_return'].max():.2%}")
print(f"Worst Trade: {trades_df['net_return'].min():.2%}")
print("=" * 50)
# Out:
# ...
# BACKTEST PERFORMANCE METRICS
# ...
# Total Trades: 457
# Win Rate: 61.71%
# Average Return per Trade: 3.74%
# Average Win: 9.02%
# Average Loss: -4.78%
# Profit Factor: 1.89
# Best Trade: 42.26%
# Worst Trade: -17.41%
# ...

# %% [markdown]
# ## 4. Cumulative Returns

# %%
# Calculate cumulative returns over time using capital
trades_df_sorted = trades_df.sort_values('entry_date')
trades_df_sorted['cumulative_return'] = (trades_df_sorted['capital_after'] / 1000000) - 1

plt.figure(figsize=(14, 6))
plt.plot(trades_df_sorted['entry_date'], 
         trades_df_sorted['cumulative_return'] * 100, 
         linewidth=2)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.5)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Return (%)', fontsize=12)
plt.title('Currency Crash Strategy - Cumulative Returns (with Risk Management)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Returns Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(trades_df['net_return'] * 100, bins=30, 
            edgecolor='black', alpha=0.7)
axes[0].axvline(0, color='r', linestyle='--', linewidth=2)
axes[0].set_xlabel('Return (%)')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Distribution of Trade Returns')
axes[0].grid(True, alpha=0.3)

# Box plot by currency
trades_df.boxplot(column='net_return', by='currency', ax=axes[1])
axes[1].set_xlabel('Currency')
axes[1].set_ylabel('Net Return')
axes[1].set_title('Returns by Currency')
plt.suptitle('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5.5. Comprehensive Strategy Dashboard

# %%
# Create a comprehensive dashboard visualization
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('Currency Crash Strategy - Comprehensive Dashboard', fontsize=16, fontweight='bold')

# 1. Cumulative PnL over time
axes[0,0].plot(trades_df_sorted['entry_date'], 
               trades_df_sorted['cumulative_return'] * 100, 
               linewidth=2, color='blue')
axes[0,0].axhline(y=0, color='r', linestyle='--', alpha=0.5)
axes[0,0].fill_between(trades_df_sorted['entry_date'], 
                       trades_df_sorted['cumulative_return'] * 100, 0, 
                       where=(trades_df_sorted['cumulative_return'] * 100 >= 0), 
                       color='green', alpha=0.3)
axes[0,0].fill_between(trades_df_sorted['entry_date'], 
                       trades_df_sorted['cumulative_return'] * 100, 0, 
                       where=(trades_df_sorted['cumulative_return'] * 100 < 0), 
                       color='red', alpha=0.3)
axes[0,0].set_title('Cumulative PnL Over Time', fontweight='bold')
axes[0,0].set_ylabel('Cumulative Return (%)')
axes[0,0].grid(True, alpha=0.3)

# 2. Trade Timeline (entry and exit points)
entry_dates = pd.to_datetime(trades_df['entry_date'])
exit_dates = pd.to_datetime(trades_df['exit_date'])
returns = trades_df['net_return'] * 100

colors = ['green' if r > 0 else 'red' for r in returns]
axes[0,1].scatter(entry_dates, returns, c=colors, alpha=0.7, s=30)
axes[0,1].axhline(y=0, color='black', linestyle='-', alpha=0.5)
axes[0,1].set_title('Trade Timeline (Entry Points)', fontweight='bold')
axes[0,1].set_ylabel('Trade Return (%)')
axes[0,1].grid(True, alpha=0.3)

# 3. Risk Metrics Summary (text-based visualization)
axes[0,2].text(0.1, 0.9, 'RISK METRICS SUMMARY', fontsize=12, fontweight='bold')
axes[0,2].text(0.1, 0.8, f'Total Return: {((final_capital / 1000000) - 1) * 100:.1f}%', fontsize=10)
axes[0,2].text(0.1, 0.7, f'Sharpe Ratio: {sharpe_ratio:.2f}', fontsize=10)
axes[0,2].text(0.1, 0.6, f'Max Drawdown: {max_drawdown:.1%}', fontsize=10)
axes[0,2].text(0.1, 0.5, f'Win Rate: {win_rate:.1%}', fontsize=10)
axes[0,2].text(0.1, 0.4, f'Profit Factor: {profit_factor:.2f}', fontsize=10)
axes[0,2].text(0.1, 0.3, f'Avg Win: {avg_win:.1%}', fontsize=10, color='green')
axes[0,2].text(0.1, 0.2, f'Avg Loss: {avg_loss:.1%}', fontsize=10, color='red')
axes[0,2].text(0.1, 0.1, f'Total Trades: {len(trades_df)}', fontsize=10)
axes[0,2].set_xlim(0, 1)
axes[0,2].set_ylim(0, 1)
axes[0,2].axis('off')

# 4. Monthly Returns Heatmap (if we can create one)
monthly_pnl = trades_df.groupby(trades_df['entry_date'].dt.to_period('M'))['net_return'].sum() * 100
monthly_pnl.index = monthly_pnl.index.to_timestamp()

# Create a simple bar chart of monthly returns
axes[1,0].bar(monthly_pnl.index, monthly_pnl.values, 
              color=['green' if x > 0 else 'red' for x in monthly_pnl.values], alpha=0.7)
axes[1,0].axhline(y=0, color='black', linestyle='-', alpha=0.5)
axes[1,0].set_title('Monthly Strategy Returns', fontweight='bold')
axes[1,0].set_ylabel('Monthly Return (%)')
axes[1,0].grid(True, alpha=0.3)

# 5. Exit Reason Distribution
exit_reasons = trades_df['exit_reason'].value_counts()
axes[1,1].pie(exit_reasons.values, labels=exit_reasons.index, autopct='%1.1f%%', 
              colors=['lightblue', 'lightgreen', 'lightcoral'])
axes[1,1].set_title('Trade Exit Reasons', fontweight='bold')

# 6. Performance by Currency (top 10)
currency_performance = trades_df.groupby('currency')['net_return'].agg(['mean', 'count']).sort_values('mean', ascending=False)
top_currencies = currency_performance.head(10)
axes[1,2].barh(top_currencies.index, top_currencies['mean'] * 100, 
                color='skyblue', alpha=0.7)
axes[1,2].set_title('Average Return by Currency (Top 10)', fontweight='bold')
axes[1,2].set_xlabel('Average Return (%)')
axes[1,2].grid(True, alpha=0.3)

plt.tight_layout()

# Save the dashboard figure
dashboard_filename = '../data/strategy_dashboard.png'
plt.savefig(dashboard_filename, dpi=300, bbox_inches='tight')
print(f"Dashboard saved as: {dashboard_filename}")

plt.show()

# Calculate in-sample/out-sample for summary
in_sample_end = pd.to_datetime(config['in_sample_end'])
in_sample = trades_df[trades_df['entry_date'] <= in_sample_end]
out_sample = trades_df[trades_df['entry_date'] > in_sample_end]

# Additional detailed metrics
summary_text = f"""
{"="*60}
STRATEGY PERFORMANCE DASHBOARD SUMMARY
{"="*60}
Backtest Period: {trades_df['entry_date'].min()} to {trades_df['entry_date'].max()}
Total Capital Growth: ${1000000:,.0f} → ${final_capital:,.0f}
Annualized Return: {(((final_capital / 1000000) ** (1/18)) - 1) * 100:.1f}%
Best Performing Currency: {currency_performance.index[0]} ({currency_performance.iloc[0]['mean']:.1%})
Worst Performing Currency: {currency_performance.index[-1]} ({currency_performance.iloc[-1]['mean']:.1%})
Most Traded Currency: {trades_df['currency'].value_counts().index[0]} ({trades_df['currency'].value_counts().iloc[0]} trades)

DETAILED RISK METRICS:
- Sharpe Ratio: {sharpe_ratio:.2f}
- Max Drawdown: {max_drawdown:.1%}
- Win Rate: {win_rate:.1%}
- Profit Factor: {profit_factor:.2f}
- Average Win: {avg_win:.1%}
- Average Loss: {avg_loss:.1%}
- Total Trades: {len(trades_df)}
- Volatility (annualized): {monthly_strategy_returns.std() * np.sqrt(12):.1%}

TRADE ANALYSIS:
- Exit Reasons: {dict(exit_reasons)}
- In-Sample Trades: {len(in_sample)} (Win Rate: {(in_sample['net_return'] > 0).mean():.1%})
- Out-of-Sample Trades: {len(out_sample)} (Win Rate: {(out_sample['net_return'] > 0).mean():.1%})
{"="*60}
"""

print(summary_text)

# Save summary to text file
summary_filename = '../data/backtest_summary.txt'
with open(summary_filename, 'w') as f:
    f.write(summary_text)
print(f"Summary saved as: {summary_filename}")

# Save enhanced trades data with additional metrics
# Merge cumulative data properly handling duplicates
cumulative_data = trades_df_sorted[['entry_date', 'cumulative_return', 'capital_after']].drop_duplicates('entry_date')
trades_df = trades_df.merge(cumulative_data, on='entry_date', how='left')
trades_df.to_csv('../data/backtest_trades_enhanced.csv', index=False)
print(f"Enhanced trades data saved as: ../data/backtest_trades_enhanced.csv")
# Out:
# Dashboard saved as: ../data/strategy_dashboard.png
# ...
# STRATEGY PERFORMANCE DASHBOARD SUMMARY
# ...
# Backtest Period: 2008-02-29 00:00:00 to 2025-12-31 00:00:00
# Total Capital Growth: $1,000,000 → $1,405,816
# Annualized Return: 1.9%
# Best Performing Currency: TRY (15.4%)
# Worst Performing Currency: CHF (-2.7%)
# Most Traded Currency: CNY (75 trades)
#
# DETAILED RISK METRICS:
# - Sharpe Ratio: 0.24
# - Max Drawdown: -29.8%
# - Win Rate: 61.7%
# - Profit Factor: 1.89
# - Average Win: 9.0%
# - Average Loss: -4.8%
# - Total Trades: 457
# - Volatility (annualized): 49.6%
#
# TRADE ANALYSIS:
# - Exit Reasons: {'time_limit': np.int64(377), 'take_profit': np.int64(48), 'stop_loss': np.int64(32)}
# - In-Sample Trades: 242 (Win Rate: 57.9%)
# - Out-of-Sample Trades: 215 (Win Rate: 66.0%)
# ...
#
# Summary saved as: ../data/backtest_summary.txt
# Enhanced trades data saved as: ../data/backtest_trades_enhanced.csv

# %%
in_sample_end = pd.to_datetime(config['in_sample_end'])

in_sample = trades_df[trades_df['entry_date'] <= in_sample_end]
out_sample = trades_df[trades_df['entry_date'] > in_sample_end]

print("IN-SAMPLE PERFORMANCE (1999-2018):")
print(f"  Trades: {len(in_sample)}")
print(f"  Win Rate: {(in_sample['net_return'] > 0).mean():.2%}")
print(f"  Avg Return: {in_sample['net_return'].mean():.2%}")

print("\nOUT-OF-SAMPLE PERFORMANCE (2019-2023):")
print(f"  Trades: {len(out_sample)}")
print(f"  Win Rate: {(out_sample['net_return'] > 0).mean():.2%}")
print(f"  Avg Return: {out_sample['net_return'].mean():.2%}")
# Out:
# IN-SAMPLE PERFORMANCE (1999-2018):
#   Trades: 242
#   Win Rate: 57.85%
#   Avg Return: 3.45%
#
# OUT-OF-SAMPLE PERFORMANCE (2019-2023):
#   Trades: 215
#   Win Rate: 66.05%
#   Avg Return: 4.06%

# %% [markdown]
# ## 7. Risk Metrics

# %%
# Calculate Sharpe ratio and drawdown from capital series
capital_series = trades_df_sorted.set_index('entry_date')['capital_after']
monthly_strategy_returns = capital_series.pct_change().dropna()

sharpe_ratio = monthly_strategy_returns.mean() / monthly_strategy_returns.std() * np.sqrt(12)
running_max = capital_series.cummax()
drawdown = (capital_series - running_max) / running_max
max_drawdown = drawdown.min()

print("RISK METRICS:")
print(f"Sharpe Ratio (annualized): {sharpe_ratio:.2f}")
print(f"Max Drawdown: {max_drawdown:.2%}")
print(f"Volatility (annualized): {monthly_strategy_returns.std() * np.sqrt(12):.2%}")
print(f"Total Return: {((final_capital / 1000000) - 1) * 100:.1f}%")
# Out:
# RISK METRICS:
# Sharpe Ratio (annualized): 0.24
# Max Drawdown: -29.80%
# Volatility (annualized): 49.56%
# Total Return: 40.6%

# %% [markdown]
# ## 8. Export Results

# %%
# Save trades to CSV
trades_df.to_csv('../data/backtest_trades.csv', index=False)
print("Backtest results saved to data/backtest_trades.csv")
print("\n=== REALISTIC BACKTEST IMPROVEMENTS ===")
print("• Carry costs: Account for interest rate differentials in FX short positions")
print("• Position sizing: Volatility-adjusted sizing (max 2% of capital per trade)")
print("• Stop-losses: Exit at -10% loss to limit downside")
print("• Take-profits: Exit at +20% gain to lock in profits")
print("• Dynamic slippage: Increases with position size for market impact")
print("• Capital tracking: Realistic compounding with position sizes")
print("• Result: 40.6% total return vs. unrealistic 19,000% before, with 29.8% max drawdown")
# Out:
# Backtest results saved to data/backtest_trades.csv
#
# === REALISTIC BACKTEST IMPROVEMENTS ===
# • Carry costs: Account for interest rate differentials in FX short positions
# • Position sizing: Volatility-adjusted sizing (max 2% of capital per trade)
# • Stop-losses: Exit at -10% loss to limit downside
# • Take-profits: Exit at +20% gain to lock in profits
# • Dynamic slippage: Increases with position size for market impact
# • Capital tracking: Realistic compounding with position sizes
# • Result: 40.6% total return vs. unrealistic 19,000% before, with 29.8% max drawdown
