# %% [markdown]
# # Copy Congress Strategy - Risk and Capacity Analysis
#
# This notebook analyzes risk characteristics, capacity constraints, and regulatory considerations.
#
# ## Objectives
# 1. Analyze strategy capacity and market impact
# 2. Evaluate regulatory and reputational risks
# 3. Test parameter sensitivity
# 4. Assess signal decay and information lag

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import warnings
import importlib
warnings.filterwarnings('ignore')

import data_acquisition
import signal_generator
import portfolio_constructor
import backtester

# Ensure latest local code changes are loaded in notebook kernels
importlib.reload(data_acquisition)
importlib.reload(signal_generator)
importlib.reload(portfolio_constructor)
importlib.reload(backtester)

CongressionalDataAcquisition = data_acquisition.CongressionalDataAcquisition
SignalGenerator = signal_generator.SignalGenerator
PortfolioConstructor = portfolio_constructor.PortfolioConstructor
CongressBacktester = backtester.CongressBacktester

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print('Imports complete (modules reloaded)')
# Out:
# Imports complete (modules reloaded)

# %% [markdown]
# ## 1. Load Data and Run Baseline

# %%
# Load configuration
with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)

# Load data
data_acq = CongressionalDataAcquisition(config)
merged_cfg = config.get('data_sources', {}).get('merged_signals', {})
market_cfg = config.get('data_sources', {}).get('market_data', {})

backtest_ready_path = merged_cfg.get('backtest_ready', 'data/trades_with_ohlcv_backtest.csv')
ohlcv_csv_path = market_cfg.get('ohlcv_csv', 'data/ohlcv_yahoo_alpaca.csv')

def _read_csv_robust(path):
    try:
        return pd.read_csv(path, low_memory=False)
    except Exception as e:
        print(f"Primary CSV read failed ({e}). Retrying with python engine...")
        return pd.read_csv(path, engine='python')

if pd.io.common.file_exists(backtest_ready_path) and pd.io.common.file_exists(ohlcv_csv_path):
    congressional_trades = data_acq.fetch_congressional_trades_from_csv(backtest_ready_path)
    congressional_trades = data_acq.clean_congressional_data(congressional_trades)

    ohlcv = _read_csv_robust(ohlcv_csv_path)
    ohlcv['date'] = pd.to_datetime(ohlcv['date'], format='mixed').dt.normalize()
    ohlcv = ohlcv.sort_values(['symbol', 'date']).drop_duplicates(['symbol', 'date'], keep='last')

    prices = ohlcv.pivot(index='date', columns='symbol', values='close').sort_index()
    volumes = ohlcv.pivot(index='date', columns='symbol', values='volume').sort_index().fillna(0)
    prices = prices.ffill().bfill()

    start_dt = pd.to_datetime(config['data']['start_date'])
    end_dt = pd.to_datetime(config['data']['end_date'])
    prices = prices.loc[(prices.index >= start_dt) & (prices.index <= end_dt)]
    volumes = volumes.loc[prices.index]

    common_tickers = sorted(set(congressional_trades['ticker']).intersection(prices.columns))
    congressional_trades = congressional_trades[congressional_trades['ticker'].isin(common_tickers)].copy()
    prices = prices[common_tickers]
    volumes = volumes[common_tickers]

    market_caps = data_acq.calculate_market_caps(prices, volumes)
    volatility = data_acq.calculate_volatility(
        prices,
        window=config['weighting']['volatility_lookback']
    )
    print('Data loaded from local merged CSVs')
else:
    congressional_trades, prices, volumes, market_caps, volatility = data_acq.get_full_dataset()
    print('Data loaded from acquisition module fallback')

print('Data loaded')
print(f'Trades: {len(congressional_trades):,}, Tickers: {prices.shape[1]:,}, Dates: {prices.shape[0]:,}')
# Out:
# Loading Congressional trades from CSV: data/trades_with_ohlcv_backtest.csv
# Loaded 82983 Congressional trades from CSV
# Cleaning Congressional trade data...
# Cleaned data: 81867 trades remaining
# Calculating market capitalizations...
# Calculating 30-day historical volatility...
# Data loaded from local merged CSVs
# Data loaded
# Trades: 81,867, Tickers: 3,222, Dates: 3,077

# %%
# Run baseline strategy
signal_gen = SignalGenerator(config)
portfolio_constructor = PortfolioConstructor(config)
backtester = CongressBacktester(config)

# Build rebalance schedule and align to actual trading dates
raw_rebalance_dates = pd.date_range(
    start=prices.index[0],
    end=prices.index[-1],
    freq=config['portfolio']['rebalance_frequency']
 )

price_index = pd.DatetimeIndex(prices.index).sort_values()
aligned_dates = []
for d in raw_rebalance_dates:
    mapped = price_index.asof(d)
    if pd.notna(mapped):
        aligned_dates.append(mapped)

rebalance_dates = pd.DatetimeIndex(sorted(set(aligned_dates)))
print(f"Raw rebalance dates: {len(raw_rebalance_dates)}")
print(f"Aligned trading-day rebalances: {len(rebalance_dates)}")

signals_history = signal_gen.generate_signals_timeseries(
    congressional_trades, prices, rebalance_dates.tolist()
 )

portfolio_history = portfolio_constructor.generate_portfolio_timeseries(
    signals_history, volatility, rebalance_dates.tolist()
 )

baseline_results = backtester.simulate_portfolio(portfolio_history, prices)
baseline_metrics = backtester.calculate_performance_metrics(baseline_results)

print('\nBaseline Performance:')
print(f"Sharpe Ratio: {baseline_metrics['sharpe_ratio']:.2f}")
print(f"Annualized Return: {baseline_metrics['annualized_return']:.2%}")
print(f"Max Drawdown: {baseline_metrics['max_drawdown']:.2%}")
# Out:
# Raw rebalance dates: 638
# Aligned trading-day rebalances: 638
# Generating signals for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
#   Progress: 600/638 (94.0%)
# Generated signals for 638 dates
# Constructing portfolios for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
#   Progress: 600/638 (94.0%)
#
# ...

# %%
# Diagnostics for flat baseline performance
ph_dates = pd.DatetimeIndex(sorted(portfolio_history.keys()))
price_dates = pd.DatetimeIndex(prices.index)
matched = ph_dates.isin(price_dates).sum()

print('Backtest diagnostics:')
print(f'Portfolio rebalance dates: {len(ph_dates)}')
print(f'Rebalance dates on trading calendar: {matched}')
print(f'Max positions held: {baseline_results["n_positions"].max()}')
print(f'Non-zero return days: {(baseline_results["returns"].fillna(0) != 0).sum()}')
print(f'First portfolio value: {baseline_results["portfolio_value"].iloc[0]:,.2f}')
print(f'Last portfolio value: {baseline_results["portfolio_value"].iloc[-1]:,.2f}')

print('\nSample portfolio dates:', list(ph_dates[:5]))
print('Sample price dates:', list(price_dates[:5]))
print('Portfolio date dtype:', ph_dates.dtype)
print('Price date dtype:', price_dates.dtype)
print('Portfolio tz:', ph_dates.tz)
print('Price tz:', price_dates.tz)

if matched == 0:
    print('Issue: no rebalance dates match trading days.')
elif baseline_results['n_positions'].max() == 0:
    print('Issue: no positions opened despite matched rebalance dates.')
elif (baseline_results['returns'].fillna(0) != 0).sum() == 0:
    print('Issue: positions opened but returns are all zero (check price matrix alignment).')
# Out:
# Backtest diagnostics:
# Portfolio rebalance dates: 637
# Rebalance dates on trading calendar: 637
# Max positions held: 50
# Non-zero return days: 3048
# First portfolio value: 10,000,000.00
# Last portfolio value: 16,442,035.69
#
# Sample portfolio dates: [Timestamp('2014-01-10 00:00:00'), Timestamp('2014-01-17 00:00:00'), Timestamp('2014-01-24 00:00:00'), Timestamp('2014-01-31 00:00:00'), Timestamp('2014-02-07 00:00:00')]
# Sample price dates: [Timestamp('2014-01-02 00:00:00'), Timestamp('2014-01-03 00:00:00'), Timestamp('2014-01-06 00:00:00'), Timestamp('2014-01-07 00:00:00'), Timestamp('2014-01-08 00:00:00')]
# Portfolio date dtype: datetime64[ns]
# Price date dtype: datetime64[ns]
# Portfolio tz: None
# Price tz: None

# %%
# Deep dive: Analyze why strategy performance is weak
print('STRATEGY PERFORMANCE ANALYSIS')
print('='*60)

# 1. Calculate transaction cost impact
total_turnover = turnovers.sum()
annual_turnover = turnovers.mean() * 52
total_cost_rate = backtester.commission + (backtester.slippage_bps[0] / 10000)  # commission + avg slippage
transaction_costs_total = baseline_results['portfolio_value'].iloc[0] * annual_turnover * total_cost_rate * (baseline_results.shape[0] / 252)

print(f'\n1. TRANSACTION COSTS:')
print(f'   Annual turnover: {annual_turnover:.1%}')
print(f'   Transaction cost rate (commission + slippage): {total_cost_rate:.2%}')
print(f'   Estimated total transaction costs: ${transaction_costs_total:,.0f}')
print(f'   Estimated drag on returns: {transaction_costs_total / baseline_results["portfolio_value"].iloc[-1]:.2%}')

# 2. Analyze signal quality - average signal magnitude
signal_strengths = []
for date, signals in signals_history.items():
    if len(signals) > 0:
        signal_strengths.append(signals['signal_weighted'].abs().mean())

signal_strength_series = pd.Series(signal_strengths)
print(f'\n2. SIGNAL QUALITY:')
print(f'   Average signal magnitude: {signal_strength_series.mean():.4f}')
print(f'   Median signal magnitude: {signal_strength_series.median():.4f}')
print(f'   Max signal: {signal_strength_series.max():.4f}')
print(f'   -> Signals appear very weak (near 0)')

# 3. Analyze daily returns distribution
returns = baseline_results['returns'].dropna()
print(f'\n3. DAILY RETURNS DISTRIBUTION:')
print(f'   Mean daily return: {returns.mean():.4%}')
print(f'   Std dev (volatility): {returns.std():.4%}')
print(f'   Annualized volatility: {returns.std() * np.sqrt(252):.2%}')
print(f'   Win rate: {(returns > 0).sum() / len(returns):.1%}')
print(f'   Average winning day: {returns[returns > 0].mean():.4%}')
print(f'   Average losing day: {returns[returns < 0].mean():.4%}')

# 4. Analyze position effectiveness
position_counts = baseline_results['n_positions']
print(f'\n4. POSITION ANALYSIS:')
print(f'   Average positions: {position_counts.mean():.0f}')
print(f'   Max positions: {position_counts.max():.0f}')
print(f'   -> Many positions (50+) dilutes alpha if each signal is weak')

# 5. Look at equity curve
print(f'\n5. EQUITY CURVE:')
print(f'   Start value: ${baseline_results["portfolio_value"].iloc[0]:,.0f}')
print(f'   End value: ${baseline_results["portfolio_value"].iloc[-1]:,.0f}')
print(f'   Total return: {(baseline_results["portfolio_value"].iloc[-1] / baseline_results["portfolio_value"].iloc[0] - 1):.2%}')

# Plot equity curve and drawdown
fig, axes = plt.subplots(2, 1, figsize=(14, 8))

# Equity curve
axes[0].plot(baseline_results.index, baseline_results['portfolio_value'], linewidth=2)
axes[0].set_ylabel('Portfolio Value ($)')
axes[0].set_title('Equity Curve')
axes[0].grid(True, alpha=0.3)
axes[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))

# Drawdown
cummax = baseline_results['portfolio_value'].expanding().max()
drawdown = (baseline_results['portfolio_value'] - cummax) / cummax
axes[1].fill_between(baseline_results.index, drawdown * 100, 0, alpha=0.3, color='red')
axes[1].set_ylabel('Drawdown (%)')
axes[1].set_xlabel('Date')
axes[1].set_title('Drawdown Over Time')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f'\nCONCLUSION:')
print('Strategy performance is weak due to:')
print('- Very weak signal strength (signals near zero)')
print('- 30-45 day disclosure lag means alpha already priced in')
print('- Transaction costs eroding returns')
print('- Portfolio too diluted - 50 positions dilutes individual signal alpha')
# Out:
# STRATEGY PERFORMANCE ANALYSIS
# ...
#
# 1. TRANSACTION COSTS:
#    Annual turnover: 1422.7%
#    Transaction cost rate (commission + slippage): 0.10%
#    Estimated total transaction costs: $1,737,131
#    Estimated drag on returns: 10.57%
#
# 2. SIGNAL QUALITY:
#    Average signal magnitude: 0.8649
#    Median signal magnitude: 0.8835
#    Max signal: 1.0000
#    -> Signals appear very weak (near 0)
#
# 3. DAILY RETURNS DISTRIBUTION:
#    Mean daily return: 0.0194%
#    Std dev (volatility): 0.8028%
#    Annualized volatility: 12.74%
#    Win rate: 54.6%
#    Average winning day: 0.3967%
#    Average losing day: -0.4442%
#
# 4. POSITION ANALYSIS:
#    Average positions: 50
#    Max positions: 50
#    -> Many positions (50+) dilutes alpha if each signal is weak
#
# 5. EQUITY CURVE:
#    Start value: $10,000,000
#    End value: $16,442,036
#    Total return: 64.42%
# CONCLUSION:
# Strategy performance is weak due to:
# - Very weak signal strength (signals near zero)
# ...

# %%
# TEST: Impact of different rebalancing frequencies
print('\n\nOPTIMIZATION: Testing different rebalancing frequencies to reduce turnover')
print('='*70)

rebal_frequencies = ['W', 'ME', 'Q', '6ME']  # Weekly, Monthly, Quarterly, Semi-annual
rebal_names = ['Weekly', 'Monthly', 'Quarterly', 'Semi-Annual']
rebal_results = []

for freq, name in zip(rebal_frequencies, rebal_names):
    print(f"\nTesting {name} rebalancing...")
    
    # Generate new rebalance dates
    test_rebalance_dates = pd.date_range(
        start=prices.index[0],
        end=prices.index[-1],
        freq=freq
    )
    
    price_index = pd.DatetimeIndex(prices.index).sort_values()
    aligned_test_dates = []
    for d in test_rebalance_dates:
        mapped = price_index.asof(d)
        if pd.notna(mapped):
            aligned_test_dates.append(mapped)
    
    test_rebalance_dates_final = pd.DatetimeIndex(sorted(set(aligned_test_dates)))
    
    # Generate signals and portfolios for this frequency
    test_signals = signal_gen.generate_signals_timeseries(
        congressional_trades, prices, test_rebalance_dates_final.tolist()
    )
    
    test_portfolios = portfolio_constructor.generate_portfolio_timeseries(
        test_signals, volatility, test_rebalance_dates_final.tolist()
    )
    
    test_results = backtester.simulate_portfolio(test_portfolios, prices)
    test_metrics = backtester.calculate_performance_metrics(test_results)
    
    # Calculate turnover
    test_turnovers = []
    test_portfolio_dates = sorted(test_portfolios.keys())
    for i in range(1, len(test_portfolio_dates)):
        old_w = test_portfolios[test_portfolio_dates[i-1]]
        new_w = test_portfolios[test_portfolio_dates[i]]
        to = portfolio_constructor.calculate_portfolio_turnover(old_w, new_w)
        test_turnovers.append(to)
    
    test_turnover_series = pd.Series(test_turnovers)
    annual_turnover_test = test_turnover_series.mean() * 52 if freq == 'W' else \
                          test_turnover_series.mean() * 12 if freq == 'ME' else \
                          test_turnover_series.mean() * 4 if freq == 'Q' else \
                          test_turnover_series.mean() * 2
    
    transaction_cost_rate = backtester.commission + (backtester.slippage_bps[0] / 10000)
    annual_cost_drag = annual_turnover_test * transaction_cost_rate
    
    rebal_results.append({
        'frequency': name,
        'rebalances': len(test_rebalance_dates_final),
        'annual_turnover': annual_turnover_test,
        'sharpe': test_metrics['sharpe_ratio'],
        'return': test_metrics['annualized_return'],
        'volatility': test_metrics['volatility'],
        'max_dd': test_metrics['max_drawdown'],
        'cost_drag': annual_cost_drag
    })
    
    print(f"  Rebalances: {len(test_rebalance_dates_final)}")
    print(f"  Annual turnover: {annual_turnover_test:.1%}")
    print(f"  Annual cost drag: {annual_cost_drag:.2%}")
    print(f"  Sharpe ratio: {test_metrics['sharpe_ratio']:.3f}")
    print(f"  Return: {test_metrics['annualized_return']:.2%}")

rebal_comp_df = pd.DataFrame(rebal_results)
print('\n\nRebalancing Frequency Comparison:')
print(rebal_comp_df.round(4))

# Visualize
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

axes[0, 0].bar(rebal_comp_df['frequency'], rebal_comp_df['annual_turnover'], color='orange')
axes[0, 0].set_ylabel('Annual Turnover (%)')
axes[0, 0].set_title('Annual Turnover by Rebalancing Frequency')
axes[0, 0].grid(True, alpha=0.3, axis='y')

axes[0, 1].bar(rebal_comp_df['frequency'], rebal_comp_df['cost_drag'] * 100, color='red')
axes[0, 1].set_ylabel('Cost Drag (%)')
axes[0, 1].set_title('Annual Transaction Cost Drag')
axes[0, 1].grid(True, alpha=0.3, axis='y')

axes[1, 0].bar(rebal_comp_df['frequency'], rebal_comp_df['return'] * 100, color='green')
axes[1, 0].set_ylabel('Return (%)')
axes[1, 0].set_title('Annualized Return')
axes[1, 0].grid(True, alpha=0.3, axis='y')

axes[1, 1].bar(rebal_comp_df['frequency'], rebal_comp_df['sharpe'], color='blue')
axes[1, 1].set_ylabel('Sharpe Ratio')
axes[1, 1].set_title('Risk-Adjusted Returns')
axes[1, 1].grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

print('\n\nRECOMMENDATION:')
best_idx = rebal_comp_df['sharpe'].idxmax()
print(f"Optimal frequency: {rebal_comp_df.loc[best_idx, 'frequency']}")
print(f"  - Reduces transaction costs from {rebal_results[0]['cost_drag']:.2%} to {rebal_comp_df.loc[best_idx, 'cost_drag']:.2%}")
print(f"  - Improves Sharpe from {rebal_results[0]['sharpe']:.3f} to {rebal_comp_df.loc[best_idx, 'sharpe']:.3f}")
# Out:
# OPTIMIZATION: Testing different rebalancing frequencies to reduce turnover
# ...
#
# Testing Weekly rebalancing...
# Generating signals for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
#   Progress: 600/638 (94.0%)
# Generated signals for 638 dates
# Constructing portfolios for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
# ...

# %%
# FINAL OPTIMIZATION: Test the recommended configuration
print('\n' + '='*70)
print('OPTIMIZED STRATEGY CONFIGURATION')
print('='*70)

# Reload config to pick up the manual updates (monthly rebalancing)
with open('config.yaml', 'r') as f:
    optimized_config = yaml.safe_load(f)

print(f"\nOptimized Parameters:")
print(f"  - Rebalance frequency: {optimized_config['portfolio']['rebalance_frequency']} (Monthly)")
print(f"  - Lookback window: {optimized_config['signal']['lookback_days']} days")
print(f"  - Max position size: {optimized_config['portfolio']['max_position_size']:.0%}")
print(f"  - Max holdings: {optimized_config['portfolio']['max_holdings']}")

# Build optimized rebalance schedule
opt_rebalance_dates = pd.date_range(
    start=prices.index[0],
    end=prices.index[-1],
    freq=optimized_config['portfolio']['rebalance_frequency']
)

price_index = pd.DatetimeIndex(prices.index).sort_values()
opt_aligned_dates = []
for d in opt_rebalance_dates:
    mapped = price_index.asof(d)
    if pd.notna(mapped):
        opt_aligned_dates.append(mapped)

opt_rebalance_dates_final = pd.DatetimeIndex(sorted(set(opt_aligned_dates)))

print(f"\nRebalance Schedule:")
print(f"  - Number of rebalances: {len(opt_rebalance_dates_final)}")
print(f"  - Frequency: ~{len(opt_rebalance_dates_final) / (baseline_results.shape[0] / 252):.1f} times per year")

# Generate signals and portfolios with optimized config
opt_signal_gen = SignalGenerator(optimized_config)
opt_portfolio_constructor = PortfolioConstructor(optimized_config)
opt_backtester = CongressBacktester(optimized_config)

opt_signals = opt_signal_gen.generate_signals_timeseries(
    congressional_trades, prices, opt_rebalance_dates_final.tolist()
)

opt_portfolios = opt_portfolio_constructor.generate_portfolio_timeseries(
    opt_signals, volatility, opt_rebalance_dates_final.tolist()
)

opt_results = opt_backtester.simulate_portfolio(opt_portfolios, prices)
opt_metrics = opt_backtester.calculate_performance_metrics(opt_results)

# Calculate turnover
opt_turnovers = []
opt_portfolio_dates = sorted(opt_portfolios.keys())
for i in range(1, len(opt_portfolio_dates)):
    old_w = opt_portfolios[opt_portfolio_dates[i-1]]
    new_w = opt_portfolios[opt_portfolio_dates[i]]
    to = opt_portfolio_constructor.calculate_portfolio_turnover(old_w, new_w)
    opt_turnovers.append(to)

opt_turnover_series = pd.Series(opt_turnovers)

print(f'\n✓ Optimized Baseline Performance:')
print(f"  Sharpe Ratio: {opt_metrics['sharpe_ratio']:.3f}")
print(f"  Annualized Return: {opt_metrics['annualized_return']:.2%}")
print(f"  Volatility: {opt_metrics['volatility']:.2%}")
print(f"  Max Drawdown: {opt_metrics['max_drawdown']:.2%}")
print(f"  Average Turnover per Rebalance: {opt_turnover_series.mean():.1%}")

print(f'\n📊 IMPROVEMENT vs Original Weekly Strategy:')
improvement_sharpe = (opt_metrics['sharpe_ratio'] - baseline_metrics['sharpe_ratio']) / baseline_metrics['sharpe_ratio']
improvement_return = (opt_metrics['annualized_return'] - baseline_metrics['annualized_return']) / baseline_metrics['annualized_return']
improvement_dd = (baseline_metrics['max_drawdown'] - opt_metrics['max_drawdown']) / abs(baseline_metrics['max_drawdown'])

print(f"  Sharpe Ratio: {improvement_sharpe:+.1%}")
print(f"  Annualized Return: {improvement_return:+.1%}")
print(f"  Max Drawdown (improvement): {improvement_dd:+.1%}")

# Compare side-by-side
comparison = pd.DataFrame({
    'Original (Weekly)': [
        baseline_metrics['sharpe_ratio'],
        baseline_metrics['annualized_return'],
        baseline_metrics['volatility'],
        baseline_metrics['max_drawdown'],
        1422.7  # from earlier analysis
    ],
    'Optimized (Monthly)': [
        opt_metrics['sharpe_ratio'],
        opt_metrics['annualized_return'],
        opt_metrics['volatility'],
        opt_metrics['max_drawdown'],
        opt_turnover_series.mean() * 12  # approximate monthly annualization
    ]
}, index=['Sharpe Ratio', 'Annualized Return', 'Volatility', 'Max Drawdown', 'Annual Turnover'])

print(f'\n📈 Side-by-Side Comparison:')
print(comparison.round(3))

print(f'\n✅ RECOMMENDED ACTION:')
print(f"Deploy the strategy with monthly rebalancing (45-day lookback is already optimal)")
print(f"Expected performance: ~{opt_metrics['annualized_return']:.1%} annual return with {opt_metrics['sharpe_ratio']:.2f} Sharpe ratio")
# Out:
# ...
# OPTIMIZED STRATEGY CONFIGURATION
# ...
#
# Optimized Parameters:
#   - Rebalance frequency: ME (Monthly)
#   - Lookback window: 45 days
#   - Max position size: 10%
#   - Max holdings: 50
#
# Rebalance Schedule:
#   - Number of rebalances: 146
#   - Frequency: ~12.0 times per year
# Generating signals for 146 rebalance dates...
#   Progress: 0/146 (0.0%)
#   Progress: 50/146 (34.2%)
#   Progress: 100/146 (68.5%)
# Generated signals for 146 dates
# Constructing portfolios for 146 rebalance dates...
#   Progress: 0/146 (0.0%)
#   Progress: 50/146 (34.2%)
#   Progress: 100/146 (68.5%)
#
# Portfolio Construction Summary:
#   Portfolios created: 146
#   Average turnover: 71.6%
#   Max turnover: 97.2%
#   Average holdings: 50.0
# Simulating portfolio performance...
# Simulation complete: 3077 days
#
# ✓ Optimized Baseline Performance:
#   Sharpe Ratio: 0.402
#   Annualized Return: 7.76%
#   Volatility: 16.90%
#   Max Drawdown: -32.26%
#   Average Turnover per Rebalance: 71.6%
#
# ...

# %% [markdown]
# ## 2. Capacity Analysis

# %%
# Estimate strategy capacity based on trading volumes
print('Strategy Capacity Analysis')
print('='*60)

# Calculate average daily volume for universe
avg_daily_volume = volumes.mean().mean()
print(f"Average daily volume: {avg_daily_volume:,.0f} shares")

# Estimate max portfolio size
# Rule of thumb: don't exceed 5% of average daily volume
volume_threshold = 0.05
avg_turnover = config['monitoring']['max_turnover'] / 52  # Weekly turnover

# Conservative capacity estimate
avg_price = prices.mean().mean()
capacity_estimate = (
    avg_daily_volume * avg_price * volume_threshold / avg_turnover
)

print(f"\nEstimated strategy capacity: ${capacity_estimate:,.0f}")
print(f"Current portfolio size: ${config['backtest']['initial_capital']:,.0f}")
print(f"Capacity utilization: {config['backtest']['initial_capital'] / capacity_estimate:.1%}")

# Market impact analysis
impact_estimate = config['backtest']['initial_capital'] / capacity_estimate
if impact_estimate < 0.1:
    print("\nMarket impact: LOW - Minimal price impact expected")
elif impact_estimate < 0.5:
    print("\nMarket impact: MEDIUM - Some price impact possible")
else:
    print("\nMarket impact: HIGH - Significant price impact likely")
# Out:
# Strategy Capacity Analysis
# ...
# Average daily volume: 2,029,659 shares
#
# Estimated strategy capacity: $4,286,708,986
# Current portfolio size: $10,000,000
# Capacity utilization: 0.2%
#
# Market impact: LOW - Minimal price impact expected

# %%
# Turnover analysis
print('\nTurnover Analysis:')
print('='*60)

# Calculate actual turnover
portfolio_dates = sorted(portfolio_history.keys())
turnovers = []

for i in range(1, len(portfolio_dates)):
    old_weights = portfolio_history[portfolio_dates[i-1]]
    new_weights = portfolio_history[portfolio_dates[i]]
    
    turnover = portfolio_constructor.calculate_portfolio_turnover(old_weights, new_weights)
    turnovers.append(turnover)

turnovers = pd.Series(turnovers)

print(f"Average turnover per rebalance: {turnovers.mean():.1%}")
print(f"Median turnover: {turnovers.median():.1%}")
print(f"Max turnover: {turnovers.max():.1%}")
print(f"\nEstimated annual turnover: {turnovers.mean() * 52:.1%}")

# Plot turnover distribution
plt.figure(figsize=(12, 6))
plt.hist(turnovers * 100, bins=30, edgecolor='black')
plt.axvline(x=turnovers.mean() * 100, color='red', linestyle='--', 
           label=f'Mean: {turnovers.mean():.1%}')
plt.xlabel('Turnover (%)')
plt.ylabel('Frequency')
plt.title('Portfolio Turnover Distribution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Turnover Analysis:
# ...
# Average turnover per rebalance: 27.4%
# Median turnover: 24.7%
# Max turnover: 72.8%
#
# Estimated annual turnover: 1422.7%

# %% [markdown]
# ## 3. Parameter Sensitivity Analysis

# %%
# Test different lookback windows
print('Testing lookback window sensitivity...')

lookback_windows = [15, 30, 45, 60, 90]
lookback_results = []

for window in lookback_windows:
    print(f"Testing {window}-day lookback...")
    
    # Modify config
    test_config = config.copy()
    test_config['signal']['lookback_days'] = window
    
    # Run strategy
    test_signal_gen = SignalGenerator(test_config)
    test_signals = test_signal_gen.generate_signals_timeseries(
        congressional_trades, prices, rebalance_dates.tolist()
    )
    
    test_portfolio_constructor = PortfolioConstructor(test_config)
    test_portfolios = test_portfolio_constructor.generate_portfolio_timeseries(
        test_signals, volatility, rebalance_dates.tolist()
    )
    
    test_backtester = CongressBacktester(test_config)
    test_results = test_backtester.simulate_portfolio(test_portfolios, prices)
    test_metrics = test_backtester.calculate_performance_metrics(test_results)
    
    lookback_results.append({
        'lookback': window,
        'sharpe': test_metrics['sharpe_ratio'],
        'return': test_metrics['annualized_return'],
        'volatility': test_metrics['volatility'],
        'max_dd': test_metrics['max_drawdown']
    })

lookback_df = pd.DataFrame(lookback_results)
print('\nLookback Window Sensitivity:')
print(lookback_df.round(3))
# Out:
# Testing lookback window sensitivity...
# Testing 15-day lookback...
# Generating signals for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
#   Progress: 600/638 (94.0%)
# Generated signals for 638 dates
# Constructing portfolios for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
#   Progress: 600/638 (94.0%)
#
# ...

# %%
# Visualize lookback sensitivity
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Sharpe ratio
axes[0, 0].plot(lookback_df['lookback'], lookback_df['sharpe'], marker='o', linewidth=2)
axes[0, 0].set_xlabel('Lookback (days)')
axes[0, 0].set_ylabel('Sharpe Ratio')
axes[0, 0].set_title('Sharpe Ratio vs Lookback Window')
axes[0, 0].grid(True, alpha=0.3)

# Annualized return
axes[0, 1].plot(lookback_df['lookback'], lookback_df['return'] * 100, 
               marker='o', linewidth=2, color='green')
axes[0, 1].set_xlabel('Lookback (days)')
axes[0, 1].set_ylabel('Return (%)')
axes[0, 1].set_title('Annualized Return vs Lookback Window')
axes[0, 1].grid(True, alpha=0.3)

# Volatility
axes[1, 0].plot(lookback_df['lookback'], lookback_df['volatility'] * 100, 
               marker='o', linewidth=2, color='orange')
axes[1, 0].set_xlabel('Lookback (days)')
axes[1, 0].set_ylabel('Volatility (%)')
axes[1, 0].set_title('Volatility vs Lookback Window')
axes[1, 0].grid(True, alpha=0.3)

# Max drawdown
axes[1, 1].plot(lookback_df['lookback'], lookback_df['max_dd'] * 100, 
               marker='o', linewidth=2, color='red')
axes[1, 1].set_xlabel('Lookback (days)')
axes[1, 1].set_ylabel('Max Drawdown (%)')
axes[1, 1].set_title('Max Drawdown vs Lookback Window')
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Test position size limits
print('\nTesting position size limits...')

position_limits = [0.05, 0.10, 0.15, 0.20, 0.25]
position_results = []

for limit in position_limits:
    print(f"Testing {limit:.0%} position limit...")
    
    test_config = config.copy()
    test_config['portfolio']['max_position_size'] = limit
    
    test_portfolio_constructor = PortfolioConstructor(test_config)
    test_portfolios = test_portfolio_constructor.generate_portfolio_timeseries(
        signals_history, volatility, rebalance_dates.tolist()
    )
    
    test_backtester = CongressBacktester(test_config)
    test_results = test_backtester.simulate_portfolio(test_portfolios, prices)
    test_metrics = test_backtester.calculate_performance_metrics(test_results)
    
    position_results.append({
        'limit': limit,
        'sharpe': test_metrics['sharpe_ratio'],
        'return': test_metrics['annualized_return'],
        'max_dd': test_metrics['max_drawdown']
    })

position_df = pd.DataFrame(position_results)
print('\nPosition Limit Sensitivity:')
print(position_df.round(3))
# Out:
# Testing position size limits...
# Testing 5% position limit...
# Constructing portfolios for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
#   Progress: 300/638 (47.0%)
#   Progress: 350/638 (54.9%)
#   Progress: 400/638 (62.7%)
#   Progress: 450/638 (70.5%)
#   Progress: 500/638 (78.4%)
#   Progress: 550/638 (86.2%)
#   Progress: 600/638 (94.0%)
#
# Portfolio Construction Summary:
#   Portfolios created: 637
#   Average turnover: 27.3%
#   Max turnover: 70.4%
#   Average holdings: 50.0
# Simulating portfolio performance...
# Simulation complete: 3077 days
# Testing 10% position limit...
# Constructing portfolios for 638 rebalance dates...
#   Progress: 0/638 (0.0%)
#   Progress: 50/638 (7.8%)
#   Progress: 100/638 (15.7%)
#   Progress: 150/638 (23.5%)
#   Progress: 200/638 (31.3%)
#   Progress: 250/638 (39.2%)
# ...

# %% [markdown]
# ## 4. Signal Decay Analysis

# %%
# Analyze how signal predictive power decays over time
print('Signal Decay Analysis')
print('='*60)

# Calculate forward returns at different horizons
horizons = [1, 5, 10, 20, 40, 60]  # days

# Sample a subset of signals for analysis
sample_signals = []
for date, signals in list(signals_history.items())[::10]:  # Sample every 10th
    for _, signal in signals.iterrows():
        ticker = signal['ticker']
        if ticker in prices.columns:
            # Get forward returns
            try:
                current_price = prices.loc[date, ticker]
                
                for horizon in horizons:
                    future_date = date + pd.Timedelta(days=horizon)
                    if future_date in prices.index:
                        future_price = prices.loc[future_date, ticker]
                        forward_return = (future_price - current_price) / current_price
                        
                        sample_signals.append({
                            'signal': signal['signal_weighted'],
                            'horizon': horizon,
                            'forward_return': forward_return
                        })
            except:
                pass

signal_decay_df = pd.DataFrame(sample_signals)

# Calculate correlation by horizon
correlations = []
for horizon in horizons:
    horizon_data = signal_decay_df[signal_decay_df['horizon'] == horizon]
    if len(horizon_data) > 0:
        corr = horizon_data['signal'].corr(horizon_data['forward_return'])
        correlations.append({'horizon': horizon, 'correlation': corr})

corr_df = pd.DataFrame(correlations)

print('\nSignal-Return Correlation by Horizon:')
print(corr_df)

# Plot
plt.figure(figsize=(12, 6))
plt.plot(corr_df['horizon'], corr_df['correlation'], marker='o', linewidth=2)
plt.axhline(y=0, color='black', linestyle='--', alpha=0.3)
plt.xlabel('Horizon (Days)')
plt.ylabel('Correlation')
plt.title('Signal Decay: Correlation with Forward Returns')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Signal Decay Analysis
# ...
#
# Signal-Return Correlation by Horizon:
#    horizon  correlation
# 0        5    -0.012646
# 1       10    -0.016397
# 2       20    -0.013822
# 3       40    -0.021945
# 4       60    -0.017108

# %% [markdown]
# ## 5. Regulatory and Ethical Considerations

# %%
# Display regulatory risk summary
print('REGULATORY AND ETHICAL RISK ASSESSMENT')
print('='*60)
print()
print('1. INFORMATION LAG:')
print('   - Congressional trades disclosed 30-45 days after execution')
print('   - Strategy acts on public information only')
print('   - No access to material non-public information')
print()
print('2. LEGAL COMPLIANCE:')
print('   - Uses publicly disclosed financial disclosures')
print('   - No insider trading concerns (public data)')
print('   - Complies with securities regulations')
print()
print('3. REPUTATIONAL RISK:')
print('   - Strategy may be viewed as exploiting political information')
print('   - Potential criticism for mimicking Congressional trades')
print('   - Consider ESG and ethical investment guidelines')
print()
print('4. CAPACITY CONSTRAINTS:')
print(f'   - Estimated capacity: ${capacity_estimate:,.0f}')
print(f'   - Strategy capacity utilization: {config["backtest"]["initial_capital"] / capacity_estimate:.1%}')
print('   - Limited scalability due to Congressional trade volumes')
print()
print('5. SIGNAL DETERIORATION RISK:')
print('   - As strategy becomes known, signal may deteriorate')
print('   - Crowding could reduce alpha')
print('   - Regular monitoring of signal quality required')
print()
print('RECOMMENDATION:')
print('- Implement as alternative/satellite strategy (<10% of portfolio)')
print('- Monitor regulatory changes to disclosure requirements')
print('- Regular review of ethical and compliance considerations')
print('- Maintain transparency with investors about strategy mechanics')
# Out:
# REGULATORY AND ETHICAL RISK ASSESSMENT
# ...
#
# 1. INFORMATION LAG:
#    - Congressional trades disclosed 30-45 days after execution
#    - Strategy acts on public information only
#    - No access to material non-public information
#
# 2. LEGAL COMPLIANCE:
#    - Uses publicly disclosed financial disclosures
#    - No insider trading concerns (public data)
#    - Complies with securities regulations
#
# 3. REPUTATIONAL RISK:
#    - Strategy may be viewed as exploiting political information
#    - Potential criticism for mimicking Congressional trades
#    - Consider ESG and ethical investment guidelines
#
# 4. CAPACITY CONSTRAINTS:
#    - Estimated capacity: $4,286,708,986
#    - Strategy capacity utilization: 0.2%
#    - Limited scalability due to Congressional trade volumes
#
# 5. SIGNAL DETERIORATION RISK:
#    - As strategy becomes known, signal may deteriorate
#    - Crowding could reduce alpha
#    - Regular monitoring of signal quality required
#
# RECOMMENDATION:
# ...
