# %% [markdown]
# # Copy Congress Strategy - Data Exploration
#
# This notebook explores Congressional trade data and market data for the Copy Congress trading strategy.
#
# ## Objectives
# 1. Load and inspect Congressional trade disclosures
# 2. Analyze trade patterns by politician, party, and committee
# 3. Explore market data for traded securities
# 4. Visualize trade flows and timing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import warnings
warnings.filterwarnings('ignore')

from data_acquisition import CongressionalDataAcquisition

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print('Imports complete')
# Out:
# Imports complete

# %% [markdown]
# ## 1. Load Configuration and Data

# %%
# Load configuration
with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)

print('Configuration loaded')
print(f"Period: {config['data']['start_date']} to {config['data']['end_date']}")
print(f"Lookback window: {config['signal']['lookback_days']} days")
# Out:
# Configuration loaded
# Period: 2014-01-02 to 2026-03-27
# Lookback window: 45 days

# %%
# Load dataset optimized for local CSV workflow
data_acq = CongressionalDataAcquisition(config)

merged_cfg = config.get('data_sources', {}).get('merged_signals', {})
market_cfg = config.get('data_sources', {}).get('market_data', {})

backtest_ready_path = merged_cfg.get('backtest_ready', 'data/trades_with_ohlcv_backtest.csv')
ohlcv_csv_path = market_cfg.get('ohlcv_csv', 'data/ohlcv_yahoo_alpaca.csv')

if pd.io.common.file_exists(backtest_ready_path) and pd.io.common.file_exists(ohlcv_csv_path):
    print(f'Loading backtest-ready trades: {backtest_ready_path}')
    congressional_trades = data_acq.fetch_congressional_trades_from_csv(backtest_ready_path)
    congressional_trades = data_acq.clean_congressional_data(congressional_trades)

    print(f'Loading OHLCV: {ohlcv_csv_path}')
    ohlcv = pd.read_csv(ohlcv_csv_path)
    ohlcv['date'] = pd.to_datetime(ohlcv['date'], format='mixed').dt.normalize()
    ohlcv = ohlcv.sort_values(['symbol', 'date']).drop_duplicates(['symbol', 'date'], keep='last')

    prices = ohlcv.pivot(index='date', columns='symbol', values='close').sort_index()
    volumes = ohlcv.pivot(index='date', columns='symbol', values='volume').sort_index().fillna(0)
    prices = prices.ffill().bfill()

    start_dt = pd.to_datetime(config['data']['start_date'])
    end_dt = pd.to_datetime(config['data']['end_date'])
    prices = prices.loc[(prices.index >= start_dt) & (prices.index <= end_dt)]
    volumes = volumes.loc[prices.index]

    common_tickers = sorted(set(congressional_trades['ticker']).intersection(prices.columns))
    congressional_trades = congressional_trades[congressional_trades['ticker'].isin(common_tickers)].copy()
    prices = prices[common_tickers]
    volumes = volumes[common_tickers]

    print('Data loaded from local merged CSVs')
else:
    print('Merged CSV files not found, falling back to acquisition module')
    congressional_trades, prices, volumes, _, _ = data_acq.get_full_dataset()

print(f'Trades: {len(congressional_trades):,}')
print(f'Price matrix: {prices.shape[0]:,} dates x {prices.shape[1]:,} tickers')
# Out:
# Loading backtest-ready trades: data/trades_with_ohlcv_backtest.csv
# Loading Congressional trades from CSV: data/trades_with_ohlcv_backtest.csv
# Loaded 82983 Congressional trades from CSV
# Cleaning Congressional trade data...
# Cleaned data: 81867 trades remaining
# Loading OHLCV: data/ohlcv_yahoo_alpaca.csv
# Data loaded from local merged CSVs
# Trades: 81,867
# Price matrix: 3,077 dates x 3,222 tickers

# %% [markdown]
# ## 2. Explore Congressional Trade Data

# %%
# Basic statistics
print('Congressional Trades Summary:')
print(f"Total trades: {len(congressional_trades):,}")
print(f"Date range: {congressional_trades['filing_date'].min()} to {congressional_trades['filing_date'].max()}")
print(f"Unique tickers: {congressional_trades['ticker'].nunique()}")
print(f"Unique politicians: {congressional_trades['politician'].nunique()}")

congressional_trades.head(10)
# Out:
# Congressional Trades Summary:
# Total trades: 81,867
# Date range: 2014-01-03 00:00:00 to 2026-03-26 00:00:00
# Unique tickers: 3222
# Unique politicians: 293
#   filing_date transaction_date   politician       party committee ticker  \
# 0  2014-01-03       2013-12-18    Bob Gibbs  Republican   Unknown    TKR
# 1  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown     CL
# 2  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown     DD
# 3  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown    GIS
# 4  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown    IBM
# 5  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown   INTC
# 6  2014-01-07       2013-12-27  Bill Flores  Republican   Unknown    CBA
# 7  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown    LLY
# 8  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown    LMT
# 9  2014-01-07       2013-12-30  Bill Flores  Republican   Unknown    CBA
#
# ...

# %%
# Trade type distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Buy vs Sell
trade_counts = congressional_trades['transaction_type'].value_counts()
axes[0].bar(trade_counts.index, trade_counts.values, color=['green', 'red'])
axes[0].set_title('Trade Type Distribution')
axes[0].set_ylabel('Number of Trades')

# Transaction amounts
axes[1].hist(congressional_trades['amount'], bins=50, edgecolor='black')
axes[1].set_title('Transaction Amount Distribution')
axes[1].set_xlabel('Amount ($)')
axes[1].set_ylabel('Frequency')
axes[1].set_yscale('log')

plt.tight_layout()
plt.show()

print(f"\nBuy ratio: {(trade_counts['buy'] / trade_counts.sum()):.1%}")
print(f"Average transaction: ${congressional_trades['amount'].mean():,.0f}")
print(f"Median transaction: ${congressional_trades['amount'].median():,.0f}")
# Out:
# Buy ratio: 50.8%
# Average transaction: $33,522
# Median transaction: $8,000

# %%
# Most traded tickers
ticker_counts = congressional_trades['ticker'].value_counts().head(20)

plt.figure(figsize=(12, 6))
plt.barh(range(len(ticker_counts)), ticker_counts.values)
plt.yticks(range(len(ticker_counts)), ticker_counts.index)
plt.xlabel('Number of Trades')
plt.title('Top 20 Most Traded Tickers by Congress')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Trades by party
if 'party' in congressional_trades.columns:
    party_stats = congressional_trades.groupby('party').agg({
        'amount': ['count', 'sum', 'mean'],
        'ticker': 'nunique'
    }).round(0)
    
    print('\nTrades by Party:')
    print(party_stats)
    
    # Visualization
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    party_counts = congressional_trades['party'].value_counts()
    axes[0].bar(party_counts.index, party_counts.values, color=['blue', 'red'])
    axes[0].set_title('Trades by Party')
    axes[0].set_ylabel('Number of Trades')
    
    party_amounts = congressional_trades.groupby('party')['amount'].sum()
    axes[1].bar(party_amounts.index, party_amounts.values, color=['blue', 'red'])
    axes[1].set_title('Total Trade Volume by Party')
    axes[1].set_ylabel('Total Amount ($)')
    
    plt.tight_layout()
    plt.show()
# Out:
# Trades by Party:
#             amount                         ticker
#              count           sum     mean nunique
# party
# Democrat     44103  1.280098e+09  29025.0    2230
# Independent     95  1.265548e+06  13322.0      59
# Republican   37669  1.462957e+09  38837.0    2337

# %%
# Trades by committee (with fallback when committee metadata is unavailable)
if 'committee' in congressional_trades.columns:
    committee_clean = congressional_trades['committee'].fillna('Unknown').astype(str).str.strip()
    known_committee = committee_clean[~committee_clean.str.lower().isin(['unknown', ''])]

    if known_committee.nunique() > 1:
        committee_stats = congressional_trades.groupby('committee').agg({
            'amount': ['count', 'sum', 'mean'],
            'ticker': 'nunique'
        }).round(0)

        committee_stats = committee_stats.sort_values(('amount', 'count'), ascending=False)

        print('\nTrades by Committee:')
        print(committee_stats)

        # Visualization
        committee_counts = congressional_trades['committee'].value_counts()
        plt.figure(figsize=(12, 6))
        plt.barh(range(len(committee_counts)), committee_counts.values)
        plt.yticks(range(len(committee_counts)), committee_counts.index)
        plt.xlabel('Number of Trades')
        plt.title('Trades by Committee')
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.show()
    else:
        print('\nCommittee metadata is not available (all values are Unknown).')
        print('Showing fallback breakdowns by chamber, party, and most active politicians instead.')

        fig, axes = plt.subplots(1, 2, figsize=(14, 5))

        if 'chamber' in congressional_trades.columns:
            chamber_counts = congressional_trades['chamber'].fillna('Unknown').value_counts()
            axes[0].bar(chamber_counts.index, chamber_counts.values, color=['#1f77b4', '#ff7f0e'])
            axes[0].set_title('Trades by Chamber')
            axes[0].set_ylabel('Number of Trades')
        else:
            party_counts = congressional_trades['party'].fillna('Unknown').value_counts()
            axes[0].bar(party_counts.index, party_counts.values, color=['#4c72b0', '#dd8452'])
            axes[0].set_title('Trades by Party')
            axes[0].set_ylabel('Number of Trades')

        top_politicians = congressional_trades['politician'].fillna('Unknown').value_counts().head(10)
        axes[1].barh(range(len(top_politicians)), top_politicians.values, color='#55a868')
        axes[1].set_yticks(range(len(top_politicians)))
        axes[1].set_yticklabels(top_politicians.index)
        axes[1].set_title('Top 10 Most Active Politicians')
        axes[1].set_xlabel('Number of Trades')
        axes[1].invert_yaxis()

        plt.tight_layout()
        plt.show()
# Out:
# Committee metadata is not available (all values are Unknown).
# Showing fallback breakdowns by chamber, party, and most active politicians instead.

# %%
# Filing delay analysis
congressional_trades['filing_delay'] = (
    congressional_trades['filing_date'] - congressional_trades['transaction_date']
).dt.days

plt.figure(figsize=(12, 6))
plt.hist(congressional_trades['filing_delay'], bins=50, edgecolor='black')
plt.xlabel('Filing Delay (Days)')
plt.ylabel('Frequency')
plt.title('Distribution of Filing Delays')
plt.axvline(congressional_trades['filing_delay'].median(), color='red', 
           linestyle='--', label=f'Median: {congressional_trades["filing_delay"].median():.0f} days')
plt.legend()
plt.tight_layout()
plt.show()

print(f"\nFiling Delay Statistics:")
print(f"Mean: {congressional_trades['filing_delay'].mean():.1f} days")
print(f"Median: {congressional_trades['filing_delay'].median():.0f} days")
print(f"Min: {congressional_trades['filing_delay'].min()} days")
print(f"Max: {congressional_trades['filing_delay'].max()} days")
# Out:
# Filing Delay Statistics:
# Mean: 47.8 days
# Median: 28 days
# Min: -344 days
# Max: 4020 days

# %% [markdown]
# ## 3. Explore Market Data

# %%
# Price data summary
print('Market Data Summary:')
print(f"Number of securities: {len(prices.columns)}")
print(f"Date range: {prices.index[0]} to {prices.index[-1]}")
print(f"Trading days: {len(prices)}")

# Sample of price evolution
sample_tickers = prices.columns[:5]
plt.figure(figsize=(12, 6))
for ticker in sample_tickers:
    normalized_prices = prices[ticker] / prices[ticker].iloc[0] * 100
    plt.plot(normalized_prices.index, normalized_prices, label=ticker)

plt.xlabel('Date')
plt.ylabel('Normalized Price (Base = 100)')
plt.title('Sample Price Evolution')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Market Data Summary:
# Number of securities: 3222
# Date range: 2014-01-02 00:00:00 to 2026-03-27 00:00:00
# Trading days: 3077

# %%
# Volatility analysis
if 'volatility' not in locals() or volatility is None:
    vol_window = config.get('weighting', {}).get('volatility_lookback', 30)
    min_vol = config.get('weighting', {}).get('min_volatility', 0.01)
    returns = prices.pct_change()
    volatility = returns.rolling(window=vol_window).std() * np.sqrt(252)
    volatility = volatility.clip(lower=min_vol)

avg_volatility = volatility.mean().sort_values(ascending=False)
avg_volatility_pct = avg_volatility * 100

# Robust statistics (reduce impact of extreme tails)
p99 = avg_volatility_pct.quantile(0.99)
trimmed = avg_volatility_pct[avg_volatility_pct <= p99]
outlier_count = (avg_volatility_pct > p99).sum()

print('\nVolatility Summary:')
print(f"Average volatility (all): {avg_volatility.mean():.1%}")
print(f"Median volatility (all): {avg_volatility.median():.1%}")
print(f"Trimmed mean (<=99th pct): {trimmed.mean()/100:.1%}")
print(f"99th percentile cap: {p99:.1f}%")
print(f"Outliers above cap: {outlier_count}")
print(f"\nTop 10 Most Volatile:")
print(avg_volatility.head(10))

# Histogram clipped at 99th percentile for readability
plt.figure(figsize=(12, 6))
plt.hist(trimmed, bins=40, edgecolor='black', alpha=0.85)
plt.xlabel('Annualized Volatility (%) [clipped at 99th percentile]')
plt.ylabel('Frequency')
plt.title('Distribution of Historical Volatility (Robust View)')
plt.axvline(trimmed.mean(), color='red', linestyle='--', label='Trimmed Mean')
plt.axvline(np.median(trimmed), color='green', linestyle='--', label='Trimmed Median')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Volatility Summary:
# Average volatility (all): 95.7%
# Median volatility (all): 26.9%
# Trimmed mean (<=99th pct): 28.5%
# 99th percentile cap: 114.1%
# Outliers above cap: 33
#
# Top 10 Most Volatile:
# symbol
# ITC      1751.079507
# AEXAY     148.950237
# TGOPY     114.527187
# TCAP       44.068536
# JET        26.962516
# RSH        17.643062
# CHRD        8.021084
# NCC         6.121841
# ALPP        5.782824
# LOCM        4.945121
# dtype: float64

# %% [markdown]
# ## 4. Time Series Analysis of Congressional Trades

# %%
# Trades over time
trades_by_month = congressional_trades.set_index('filing_date').resample('M').size()

plt.figure(figsize=(14, 6))
plt.plot(trades_by_month.index, trades_by_month.values, linewidth=2)
plt.xlabel('Date')
plt.ylabel('Number of Trades')
plt.title('Congressional Trades Over Time (Monthly)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\nAverage trades per month: {trades_by_month.mean():.1f}")
# Out:
# Average trades per month: 556.9

# %%
# Net buy/sell flow over time (robust visualization)
congressional_trades['net_flow'] = congressional_trades.apply(
    lambda x: x['amount'] if x['transaction_type'] == 'buy' else -x['amount'], axis=1
)

monthly_flow = congressional_trades.set_index('filing_date').resample('M')['net_flow'].sum()
monthly_flow_m = monthly_flow / 1e6

# Clip extremes for readability while preserving sign
cap = monthly_flow_m.abs().quantile(0.95)
monthly_flow_clip = monthly_flow_m.clip(lower=-cap, upper=cap)
outlier_months = (monthly_flow_m.abs() > cap).sum()

# 3-month rolling average to show trend
rolling_3m = monthly_flow_m.rolling(3, min_periods=1).mean()

fig, axes = plt.subplots(2, 1, figsize=(14, 10), sharex=True)

# Panel 1: clipped bars (readable)
colors_clip = ['green' if x > 0 else 'red' for x in monthly_flow_clip]
axes[0].bar(monthly_flow_clip.index, monthly_flow_clip.values, color=colors_clip, alpha=0.85, width=25)
axes[0].axhline(y=0, color='black', linestyle='-', linewidth=0.7)
axes[0].set_ylabel('Net Flow ($ Millions)')
axes[0].set_title('Congressional Net Buy/Sell Flow (Clipped at 95th Percentile)')
axes[0].grid(True, alpha=0.3)

# Panel 2: full flow + trend
colors_full = ['green' if x > 0 else 'red' for x in monthly_flow_m]
axes[1].bar(monthly_flow_m.index, monthly_flow_m.values, color=colors_full, alpha=0.5, width=25, label='Monthly Net Flow')
axes[1].plot(rolling_3m.index, rolling_3m.values, color='navy', linewidth=2.0, label='3M Rolling Mean')
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.7)
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Net Flow ($ Millions)')
axes[1].set_title('Congressional Net Buy/Sell Flow (Full Scale + Trend)')
axes[1].grid(True, alpha=0.3)
axes[1].legend()

plt.tight_layout()
plt.show()

print('Net Flow Summary:')
print(f'Total months: {len(monthly_flow_m)}')
print(f'Mean monthly flow: ${monthly_flow_m.mean():.2f}M')
print(f'Median monthly flow: ${monthly_flow_m.median():.2f}M')
print(f'95% clip level: +/- ${cap:.2f}M')
print(f'Outlier months beyond clip: {outlier_months}')
# Out:
# Net Flow Summary:
# Total months: 147
# Mean monthly flow: $-0.29M
# Median monthly flow: $-0.31M
# 95% clip level: +/- $19.31M
# Outlier months beyond clip: 8

# %% [markdown]
# ## 5. Correlation Analysis

# %%
# Sample correlation matrix
sample_tickers = congressional_trades['ticker'].value_counts().head(10).index
sample_prices = prices[sample_tickers]
sample_returns = sample_prices.pct_change().dropna()

correlation_matrix = sample_returns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
           square=True, linewidths=1, cbar_kws={'label': 'Correlation'})
plt.title('Return Correlation Matrix - Top 10 Traded Stocks')
plt.tight_layout()
plt.show()
